# %% [markdown]
# # Birds, climate and range shifts
#
# Notebook template for the final submission.

# %% [markdown]
# ## 1. Imports and setup

# %%
from pathlib import Path
import sys

import pandas as pd
import plotly.express as px

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from climate_birds.config import PROCESSED_DIR

# %% [markdown]
# ## 2. Load processed data

# %%
panel = pd.read_csv(PROCESSED_DIR / 'analysis_panel.csv')
trends = pd.read_csv(PROCESSED_DIR / 'population_trends.csv')
panel.head()

# %% [markdown]
# ## 3. Pre-processing notes

# %% [markdown]
# ## 4. Visual analysis

# %% [markdown]
# ## 5. Statistical analysis

# %% [markdown]
# ## 6. Advanced analysis

# %% [markdown]
# ## 7. Conclusions
